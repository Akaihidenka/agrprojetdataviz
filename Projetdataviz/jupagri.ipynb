# %%
import streamlit as st
import pandas as pd

url = "https://koumoul.com/data-fair/api/v1/datasets/agribalyse-31-synthese/raw"
st.title("Visualisation initiale du dataset Agribalyse_Synthese")
df = pd.read_csv(url)
st.write(df)

# %%
pd.set_option('display.max_columns', None)
df
# Out:
#      Code AGB  Code CIQUAL                        Groupe d'aliment  \
# 0       11084        11084  aides culinaires et ingrédients divers
# 1       11023        11023  aides culinaires et ingrédients divers
# 2       11000        11000  aides culinaires et ingrédients divers
# 3       11093        11093  aides culinaires et ingrédients divers
# 4       20995        20995  aides culinaires et ingrédients divers
# ...       ...          ...                                     ...
# 2513     6535         6535                 viandes, œufs, poissons
# 2514     6582         6582                 viandes, œufs, poissons
# 2515    26146        26146                 viandes, œufs, poissons
# 2516    26147        26147                 viandes, œufs, poissons
# 2517    25512        25512                 viandes, œufs, poissons
#
#                  Sous-groupe d'aliment  \
# 0                               algues
# 1                               herbes
# 2                               herbes
# 3                               herbes
# 4                               algues
# ...                                ...
# 2513                     viandes crues
# 2514                    viandes cuites
# 2515                     poissons crus
# 2516                    poissons cuits
# 2517  autres produits à base de viande
#
#                              Nom du Produit en Français  \
# 0                                     Agar (algue), cru
# 1                                     Ail séché, poudre
# 2                                              Ail, cru
# 3                                          Aneth, frais
# 4     Ao-nori (Enteromorpha sp.), séchée ou déshydratée
# ...                                                 ...
# 2513                      Veau, steak haché 20% MG, cru
# 2514                 Veau, tête, bouillie/cuite à l'eau
# 2515                                      Vivaneau, cru
# 2516                                     Vivaneau, cuit
# 2517               Volaille, croquette panée ou nuggets
#
#                                                LCI Name  code saison  \
# 0                                    Seaweed, agar, raw            2
# 1                                 Garlic, powder, dried            2
# 2                                         Garlic, fresh            2
# 3                                           Dill, fresh            2
# 4     Sea lettuce (Enteromorpha sp.), dried or dehyd...            2
# ...                                                 ...          ...
# 2513                   Veal, minced steak, 20% fat, raw            2
# 2514                 Calf, head, boiled/cooked in water            2
# 2515                                       Snapper, raw            2
# 2516                                    Snapper, cooked            2
# 2517                                    Poultry nuggets            2
#
#       code avion       Livraison Matériau d'emballage         Préparation  \
# 0              0  Ambiant (long)                 LDPE  Pas de préparation
# 1              0  Ambiant (long)                Verre  Pas de préparation
# 2              0  Ambiant (long)      Pas d'emballage  Pas de préparation
# 3              0  Ambiant (long)                 LDPE  Pas de préparation
# 4              0  Ambiant (long)                 LDPE  Pas de préparation
# ...          ...             ...                  ...                 ...
# 2513           0           Glacé                   PS  Pas de préparation
# 2514           0           Glacé                   PS     Cuisson à l'eau
# 2515           0           Glacé                   PS  Pas de préparation
# 2516           0           Glacé                   PP                Four
# 2517           0           Glacé                   PS               Four
#
#        DQR  Score unique EF  Changement climatique  \
# 0     2.99         1.226025               6.745806
# 1     4.11         0.103513               0.750274
# 2     3.54         0.064652               0.358043
# 3     3.75         0.131581               0.813436
# 4     2.99         1.226025               6.745806
# ...    ...              ...                    ...
# 2513  2.47         2.149621              22.366989
# 2514  2.45         2.231243              23.466474
# 2515  3.68         0.810828               4.235541
# 2516  3.56         1.018584               5.146610
# 2517  2.79         0.843744               5.910328
#
#       Appauvrissement de la couche d'ozone  Rayonnements ionisants  \
# 0                             1.017147e-06               11.050022
# 1                             1.229332e-07                0.172269
# 2                             5.483998e-08                0.143971
# 3                             6.268829e-08                0.141342
# 4                             1.017147e-06               11.050022
# ...                                    ...                     ...
# 2513                          7.076711e-07                1.870429
# 2514                          7.697675e-07                1.681044
# 2515                          7.763385e-07                0.425344
# 2516                          9.573809e-07                1.118427
# 2517                          7.296397e-07                3.137404
#
#       Formation photochimique d'ozone  Particules fines  \
# 0                            0.038875      7.172887e-07
# 1                            0.002936      8.262876e-08
# 2                            0.001081      2.344885e-08
# 3                            0.002559      6.896720e-08
# 4                            0.038875      7.172887e-07
# ...                               ...               ...
# 2513                         0.041809      1.522429e-06
# 2514                         0.043821      1.576161e-06
# 2515                         0.064757      7.255289e-07
# 2516                         0.079025      8.874895e-07
# 2517                         0.013217      7.374327e-07
#
#       Effets toxicologiques sur la santé humaine : substances non-cancérogènes  \
# 0                                          4.771949e-08
# 1                                          9.281982e-09
# 2                                          6.066248e-09
# 3                                          9.739990e-09
# 4                                          4.771949e-08
# ...                                                 ...
# 2513                                       3.264653e-07
# 2514                                       3.372234e-07
# 2515                                       6.634146e-08
# 2516                                       8.251411e-08
# 2517                                       5.620017e-08
#
#       Effets toxicologiques sur la santé humaine : substances cancérogènes  \
# 0                                          6.108019e-09
# 1                                          4.343632e-10
# 2                                          2.824785e-10
# 3                                          5.867577e-10
# 4                                          6.108019e-09
# ...                                                 ...
# 2513                                       9.700195e-09
# 2514                                       1.004739e-08
# 2515                                       3.674589e-09
# 2516                                       4.570590e-09
# 2517                                       4.250543e-09
#
#       Acidification terrestre et eaux douces  Eutrophisation eaux douces  \
# 0                                   0.099733                    0.001868
# 1                                   0.006246                    0.000125
# 2                                   0.002036                    0.000069
# 3                                   0.008112                    0.000203
# 4                                   0.099733                    0.001868
# ...                                      ...                         ...
# 2513                                0.224634                    0.002196
# 2514                                0.232052                    0.002280
# 2515                                0.095432                    0.000677
# 2516                                0.116709                    0.000867
# 2517                                0.102592                    0.000963
#
#       Eutrophisation marine  Eutrophisation terrestre  \
# 0                  0.013280                  0.127350
# 1                  0.002379                  0.012785
# 2                  0.002197                  0.006394
# 3                  0.004050                  0.031181
# 4                  0.013280                  0.127350
# ...                     ...                       ...
# 2513               0.155377                  0.960270
# 2514               0.160210                  0.990441
# 2515               0.022499                  0.244290
# 2516               0.027545                  0.298742
# 2517               0.026205                  0.436260
#
#       Écotoxicité pour écosystèmes aquatiques d'eau douce  Utilisation du sol  \
# 0                                             43.368466             24.699395
# 1                                              5.672531             20.508995
# 2                                              4.064650             18.871203
# 3                                              5.534832             36.288833
# 4                                             43.368466             24.699395
# ...                                                 ...                   ...
# 2513                                         186.474798           1487.575200
# 2514                                         193.771937           1532.143500
# 2515                                          22.496671             14.247462
# 2516                                          27.343587             18.070403
# 2517                                          76.877339            317.114250
#
#       Épuisement des ressources eau  Épuisement des ressources énergétiques  \
# 0                          3.079121                              315.057170
# 1                          2.585763                               12.701604
# 2                          3.104146                                6.275385
# 3                          5.290335                               12.553109
# 4                          3.079121                              315.057170
# ...                             ...                                     ...
# 2513                       6.308089                              111.066140
# 2514                       6.549523                              115.201390
# 2515                       0.551758                               60.601249
# 2516                       0.633008                               86.252396
# 2517                       4.168684                               95.759859
#
#       Épuisement des ressources minéraux
# 0                               0.000088
# 1                               0.000007
# 2                               0.000004
# 3                               0.000005
# 4                               0.000088
# ...                                  ...
# 2513                            0.000037
# 2514                            0.000040
# 2515                            0.000163
# 2516                            0.000203
# 2517                            0.000024
#
# [2518 rows x 29 columns]

# %%
# Supprimer les colonnes non nécessaires
colonnes_a_conserver = [
    'Code AGB', 'Groupe d\'aliment','Sous-groupe d\'aliment',
    'Nom du Produit en Français','Acidification terrestre et eaux douces','Eutrophisation eaux douces','Épuisement des ressources eau'
]

df2 = df[colonnes_a_conserver]

# %%
df2
# Out:
#      Code AGB                        Groupe d'aliment  \
# 0       11084  aides culinaires et ingrédients divers
# 1       11023  aides culinaires et ingrédients divers
# 2       11000  aides culinaires et ingrédients divers
# 3       11093  aides culinaires et ingrédients divers
# 4       20995  aides culinaires et ingrédients divers
# ...       ...                                     ...
# 2513     6535                 viandes, œufs, poissons
# 2514     6582                 viandes, œufs, poissons
# 2515    26146                 viandes, œufs, poissons
# 2516    26147                 viandes, œufs, poissons
# 2517    25512                 viandes, œufs, poissons
#
#                  Sous-groupe d'aliment  \
# 0                               algues
# 1                               herbes
# 2                               herbes
# 3                               herbes
# 4                               algues
# ...                                ...
# 2513                     viandes crues
# 2514                    viandes cuites
# 2515                     poissons crus
# 2516                    poissons cuits
# 2517  autres produits à base de viande
#
#                              Nom du Produit en Français  \
# 0                                     Agar (algue), cru
# 1                                     Ail séché, poudre
# 2                                              Ail, cru
# 3                                          Aneth, frais
# 4     Ao-nori (Enteromorpha sp.), séchée ou déshydratée
# ...                                                 ...
# 2513                      Veau, steak haché 20% MG, cru
# 2514                 Veau, tête, bouillie/cuite à l'eau
# 2515                                      Vivaneau, cru
# 2516                                     Vivaneau, cuit
# 2517               Volaille, croquette panée ou nuggets
#
#       Acidification terrestre et eaux douces  Eutrophisation eaux douces  \
# 0                                   0.099733                    0.001868
# 1                                   0.006246                    0.000125
# 2                                   0.002036                    0.000069
# 3                                   0.008112                    0.000203
# 4                                   0.099733                    0.001868
# ...                                      ...                         ...
# 2513                                0.224634                    0.002196
# 2514                                0.232052                    0.002280
# 2515                                0.095432                    0.000677
# 2516                                0.116709                    0.000867
# 2517                                0.102592                    0.000963
#
#       Épuisement des ressources eau
# 0                          3.079121
# 1                          2.585763
# 2                          3.104146
# 3                          5.290335
# 4                          3.079121
# ...                             ...
# 2513                       6.308089
# 2514                       6.549523
# 2515                       0.551758
# 2516                       0.633008
# 2517                       4.168684
#
# [2518 rows x 7 columns]

# %%
# Supprimer les doublons
df2.drop_duplicates(inplace=True)
# Out:
# /var/folders/7t/hzxzbjh54kj290pzr4chfmph0000gn/T/ipykernel_39081/3043172330.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop_duplicates(inplace=True)

# %%
# Afficher le dataset après nettoyage
st.title("Dataset après nettoyage")
df2
# Out:
#      Code AGB                        Groupe d'aliment  \
# 0       11084  aides culinaires et ingrédients divers
# 1       11023  aides culinaires et ingrédients divers
# 2       11000  aides culinaires et ingrédients divers
# 3       11093  aides culinaires et ingrédients divers
# 4       20995  aides culinaires et ingrédients divers
# ...       ...                                     ...
# 2513     6535                 viandes, œufs, poissons
# 2514     6582                 viandes, œufs, poissons
# 2515    26146                 viandes, œufs, poissons
# 2516    26147                 viandes, œufs, poissons
# 2517    25512                 viandes, œufs, poissons
#
#                  Sous-groupe d'aliment  \
# 0                               algues
# 1                               herbes
# 2                               herbes
# 3                               herbes
# 4                               algues
# ...                                ...
# 2513                     viandes crues
# 2514                    viandes cuites
# 2515                     poissons crus
# 2516                    poissons cuits
# 2517  autres produits à base de viande
#
#                              Nom du Produit en Français  \
# 0                                     Agar (algue), cru
# 1                                     Ail séché, poudre
# 2                                              Ail, cru
# 3                                          Aneth, frais
# 4     Ao-nori (Enteromorpha sp.), séchée ou déshydratée
# ...                                                 ...
# 2513                      Veau, steak haché 20% MG, cru
# 2514                 Veau, tête, bouillie/cuite à l'eau
# 2515                                      Vivaneau, cru
# 2516                                     Vivaneau, cuit
# 2517               Volaille, croquette panée ou nuggets
#
#       Acidification terrestre et eaux douces  Eutrophisation eaux douces  \
# 0                                   0.099733                    0.001868
# 1                                   0.006246                    0.000125
# 2                                   0.002036                    0.000069
# 3                                   0.008112                    0.000203
# 4                                   0.099733                    0.001868
# ...                                      ...                         ...
# 2513                                0.224634                    0.002196
# 2514                                0.232052                    0.002280
# 2515                                0.095432                    0.000677
# 2516                                0.116709                    0.000867
# 2517                                0.102592                    0.000963
#
#       Épuisement des ressources eau
# 0                          3.079121
# 1                          2.585763
# 2                          3.104146
# 3                          5.290335
# 4                          3.079121
# ...                             ...
# 2513                       6.308089
# 2514                       6.549523
# 2515                       0.551758
# 2516                       0.633008
# 2517                       4.168684
#
# [2518 rows x 7 columns]

# %% [markdown]
# 1. Visualisation des données

# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Visualisation de la consommation d'eau par type de produit
st.title("Consommation d'eau par type de produit")
fig, ax = plt.subplots(figsize=(10,6))
sns.barplot(data=df2, x='Groupe d\'aliment', y='Épuisement des ressources eau', ax=ax)
st.pyplot(fig)
# Out:
# DeltaGenerator()

# %% [markdown]
# 3. Comparaisons

# %%
produit_1, produit_2 = st.multiselect(
    'Sélectionne deux produits pour la comparaison',
    df['Groupe d\'aliment'].unique(), default=df['Groupe d\'aliment'].unique()[:2])

if len([produit_1, produit_2]) == 2:
    df_compare = df[df['Groupe d\'aliment'].isin([produit_1, produit_2])]
    st.bar_chart(df_compare.groupby('Groupe d\'aliment').sum())
# Out:
# /var/folders/7t/hzxzbjh54kj290pzr4chfmph0000gn/T/ipykernel_39081/173283127.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   st.bar_chart(df_compare.groupby('Groupe d\'aliment').sum())

# %% [markdown]
# Histogramme de la consommation d'eau:

# %%
# Filtrer les données pour éliminer les valeurs extrêmes (par exemple, en conservant les valeurs entre les percentiles 5 et 95)
lower_bound = df2['Épuisement des ressources eau'].quantile(0.05)
upper_bound = df2['Épuisement des ressources eau'].quantile(0.95)
filtered_data = df2[(df2['Épuisement des ressources eau'] >= lower_bound) & (df2['Épuisement des ressources eau'] <= upper_bound)]

# Tracer l'histogramme
sns.histplot(filtered_data['Épuisement des ressources eau'], kde=True)
plt.title("Distribution zoomée de la consommation d'eau")
plt.xlabel("Consommation d'eau")
plt.ylabel("Nombre de produits")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Diagramme en barres montrant la consommation moyenne d'eau par groupe d'aliment:

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Groupe d\'aliment', y='Épuisement des ressources eau', data=df2, ci=None)
plt.title("Consommation moyenne d'eau par groupe d'aliment")
plt.xlabel("Groupe d'aliment")
plt.ylabel("Consommation moyenne d'eau")
plt.xticks(rotation=45)
plt.show()
# Out:
# /var/folders/7t/hzxzbjh54kj290pzr4chfmph0000gn/T/ipykernel_39081/82666449.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Groupe d\'aliment', y='Épuisement des ressources eau', data=df2, ci=None)

# %% [markdown]
# Box plot pour comparer la consommation d'eau entre différents groupes d'aliments:

# %%
# Boxplot pour la consommation d'eau par groupe d'aliment, sans valeurs aberrantes
plt.figure(figsize=(15, 7))
sns.boxplot(data=df2, x='Groupe d\'aliment', y='Épuisement des ressources eau', showfliers=False)
plt.title('Distribution de la consommation d\'eau par groupe d\'aliment (sans valeurs aberrantes)')
plt.xticks(rotation=45)
plt.xlabel('Groupe d\'aliment')
plt.ylabel('Consommation d\'eau (Épuisement des ressources eau)')
plt.show()

# %%
# Boxplot pour Acidification terrestre et eaux douces par groupe d'aliment, sans valeurs aberrantes
plt.figure(figsize=(15, 7))
sns.boxplot(data=df2, x='Groupe d\'aliment', y='Acidification terrestre et eaux douces', showfliers=False)
plt.title('Distribution de l\'Acidification terrestre et eaux douces par groupe d\'aliment (sans valeurs aberrantes)')
plt.xticks(rotation=45)
plt.xlabel('Groupe d\'aliment')
plt.ylabel('Acidification terrestre et eaux douces')
plt.show()

# Boxplot pour Eutrophisation eaux douces par groupe d'aliment, sans valeurs aberrantes
plt.figure(figsize=(15, 7))
sns.boxplot(data=df2, x='Groupe d\'aliment', y='Eutrophisation eaux douces', showfliers=False)
plt.title('Distribution de l\'Eutrophisation eaux douces par groupe d\'aliment (sans valeurs aberrantes)')
plt.xticks(rotation=45)
plt.xlabel('Groupe d\'aliment')
plt.ylabel('Eutrophisation eaux douces')
plt.show()

# %%
groupes_aliment = df2['Groupe d\'aliment'].unique()

for groupe in groupes_aliment:
    data_subset = df2[df2['Groupe d\'aliment'] == groupe]
    
    # Calculer la somme pour chaque sous-groupe d'aliment
    sum_data = data_subset.groupby('Sous-groupe d\'aliment')[['Épuisement des ressources eau', 'Acidification terrestre et eaux douces', 'Eutrophisation eaux douces']].sum()
    
    # Tracer le graphique à barres empilées
    ax = sum_data.plot(kind='bar', stacked=True, figsize=(12, 6))
    plt.title(f"Répartition pour le groupe d'aliment : {groupe}")
    plt.ylabel('Valeur')
    plt.xlabel('Sous-groupe d\'aliment')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
    
    # Identifier l'élément qui utilise le plus d'eau
    max_water_product = data_subset[data_subset['Épuisement des ressources eau'] == data_subset['Épuisement des ressources eau'].max()]['Nom du Produit en Français'].values[0]
    print(f"Dans le groupe d'aliment '{groupe}', l'élément '{max_water_product}' utilise le plus d'eau.\n")
# Out:
# Dans le groupe d'aliment 'aides culinaires et ingrédients divers', l'élément 'Son de riz' utilise le plus d'eau.
# Dans le groupe d'aliment 'aliments infantiles', l'élément 'Boisson aux fruits pour bébé dès 4/6mois' utilise le plus d'eau.
# Dans le groupe d'aliment 'boissons', l'élément 'Jus de pamplemousse (pomelo), pur jus' utilise le plus d'eau.
# Dans le groupe d'aliment 'entrées et plats composés', l'élément 'Sushi ou Maki aux produits de la mer' utilise le plus d'eau.
# Dans le groupe d'aliment 'fruits, légumes, légumineuses et oléagineux', l'élément 'Pêche, sèche' utilise le plus d'eau.
# Dans le groupe d'aliment 'glaces et sorbets', l'élément 'Sorbet, bâtonnet' utilise le plus d'eau.
# Dans le groupe d'aliment 'lait et produits laitiers', l'élément 'Clafoutis aux fruits, rayon frais' utilise le plus d'eau.
# Dans le groupe d'aliment 'matières grasses', l'élément 'Huile d'avocat' utilise le plus d'eau.
# Dans le groupe d'aliment 'produits céréaliers', l'élément 'Riz thaï ou basmati, cru' utilise le plus d'eau.
# Dans le groupe d'aliment 'produits sucrés', l'élément 'Confiture de cerise (extra ou classique)' utilise le plus d'eau.
# Dans le groupe d'aliment 'viandes, œufs, poissons', l'élément 'Panga, Pangasius, ou poisson-chat du Mékong, filet, cuit' utilise le plus d'eau.

# %%
# Tri du DataFrame en fonction de l'épuisement des ressources d'eau et prise des 30 premiers produits
top_eau = df2.sort_values(by='Épuisement des ressources eau', ascending=False).head(30)

# Affichage des 'Nom du Produit en Français' de ces produits
for produit in top_eau['Nom du Produit en Français']:
    print(produit)
# Out:
# Panga, Pangasius, ou poisson-chat du Mékong, filet, cuit
# Perche, rôtie/cuite au four
# Pêche, sèche
# Perche, crue
# Omble chevalier, cru
# Pruneau, sec
# Riz thaï ou basmati, cru
# Huile d'avocat
# Farine de riz
# Quinoa FR, cru
# Riz blanc, cru
# Riz rouge, cru
# Riz, mélange de variétés (blanc, complet, rouge, sauvage, etc.), cru
# Riz complet, cru
# Riz sauvage, cru
# Riz blanc étuvé, cru
# Pamplemousse chinois, pulpe, cru
# Figue, sèche
# Jus de pamplemousse (pomelo), pur jus
# Huile de coton
# Noix, séchée, cerneaux
# Noix, fraîche
# Noix de macadamia
# Noix de pécan, salées
# Noix de pécan
# Noix de macadamia, grillée, salée
# Truite arc en ciel, élevage, cuite à la vapeur
# Carpe, rôtie/cuite au four
# Truite arc en ciel, élevage, rôtie/cuite au four
# Truite, rôtie/cuite au four

# %% [markdown]
# 2. Filtres personnalisés

# %%
import streamlit as st
import pandas as pd



# Widget pour choisir un sous-groupe d'aliment
sous_groupe = st.selectbox('Choisis un sous-groupe d\'aliment', df2['Sous-groupe d\'aliment'].unique())

# Filtrage du dataframe selon le sous-groupe choisi
df_sous_groupe = df2[df2['Sous-groupe d\'aliment'] == sous_groupe]

# Widget pour choisir un 'nom de produit en français'
produit = st.selectbox('Choisis un produit', df_sous_groupe['Nom du Produit en Français'].unique())

# Affichage de la consommation d'eau du produit choisi
eau_produit = df_sous_groupe[df_sous_groupe['Nom du Produit en Français'] == produit]['Épuisement des ressources eau'].values[0]
st.write(f"Consommation d'eau de {produit}: {eau_produit}")

# Si le produit choisi utilise trop d'eau (ici, je prends un seuil arbitraire, tu peux le changer)
seuil = 100  # Remplace cette valeur par le seuil que tu juges approprié
if eau_produit > seuil:
    # Trouver un autre produit du même sous-groupe qui utilise moins d'eau
    alternative = df_sous_groupe[df_sous_groupe['Épuisement des ressources eau'] < eau_produit].sort_values(by='Épuisement des ressources eau').head(1)['Nom du Produit en Français'].values[0]
    st.write(f"Pour économiser de l'eau, tu pourrais envisager de consommer {alternative} à la place de {produit}!")

# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt


# Widget pour choisir un groupe d'aliment
groupe = st.selectbox('Choisis un groupe d\'aliment', df2['Groupe d\'aliment'].unique())

# Filtrage du dataframe selon le groupe choisi
df_groupe = df2[df2['Groupe d\'aliment'] == groupe]

# Widgets pour choisir deux produits
produit1 = st.selectbox('Choisis le premier produit', df_groupe['Nom du Produit en Français'].unique())
produit2 = st.selectbox('Choisis le second produit', df_groupe[df_groupe['Nom du Produit en Français'] != produit1]['Nom du Produit en Français'].unique())

# Extraction des données des produits choisis
data_produit1 = df_groupe[df_groupe['Nom du Produit en Français'] == produit1][['Épuisement des ressources eau', 'Acidification terrestre et eaux douces', 'Eutrophisation eaux douces']].values[0]
data_produit2 = df_groupe[df_groupe['Nom du Produit en Français'] == produit2][['Épuisement des ressources eau', 'Acidification terrestre et eaux douces', 'Eutrophisation eaux douces']].values[0]

# Affichage des comparaisons
labels = ['Épuisement des ressources eau', 'Acidification terrestre et eaux douces', 'Eutrophisation eaux douces']

x = range(len(labels))
plt.bar(x, data_produit1, width=0.4, label=produit1, color='b', align='center')
plt.bar(x, data_produit2, width=0.4, label=produit2, color='r', bottom=data_produit1, align='edge')

plt.xlabel('Critères')
plt.ylabel('Valeur')
plt.title('Comparaison des produits')
plt.xticks(x, labels)
plt.legend()
plt.tight_layout()
st.pyplot()

# Conseil sur le produit qui utilise moins d'eau
if data_produit1[0] < data_produit2[0]:
    st.write(f"{produit1} utilise moins d'eau que {produit2}.")
else:
    st.write(f"{produit2} utilise moins d'eau que {produit1}.")
